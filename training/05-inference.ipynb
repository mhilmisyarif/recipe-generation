# %%
import importlib
import os

conditional_gen_dir = importlib.import_module("src.conditional_gen_dir")
save = importlib.import_module("src.save")
# Out:
# d:\SKIRPSI\Project\indo-recipe-generation\venv36\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\SKIRPSI\Project\indo-recipe-generation\venv36\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\SKIRPSI\Project\indo-recipe-generation\venv36\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
os.environ['CUDA_VISIBLE_DEVICES']='0'

# %%
task_name = 'scratch'

task_params = {'top_k': 3, 'model_name': task_name,
            'filename': '../files/test/X/', 'overwrite': True,
            'tag': '_%s_k3_test'%(task_name)}
to_write = {'to_write': 'model_checkpoint_path: "model-115"\n'}
modelpath = {'modelpath':'models/%s/checkpoint'%(task_name)}

save.save(modelpath['modelpath'], to_write['to_write'], overwrite=True)

conditional_gen_dir.interact_model(**task_params)
# Out:
# saved models/scratch/checkpoint
# 100%|██████████| 15750/15750 [02:45<00:00, 95.43it/s]
# time spent in encoding 0:02:45.326535
# INFO:tensorflow:Restoring parameters from D:\SKIRPSI\Project\indo-recipe-generation\notebooks\models\scratch\model-115
# start decoding 2022-10-20 21:41:50.703758
#   0%|          | 0/15750 [00:00<?, ?it/s]
# make dir
#   0%|          | 2/15750 [07:29<864:00:24, 197.51s/it]
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# d:\SKIRPSI\Project\indo-recipe-generation\venv36\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# d:\SKIRPSI\Project\indo-recipe-generation\venv36\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
# ...
